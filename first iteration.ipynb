# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def initialize_map(lab_map: np.ndarray -> tuple:
    """This function's goal is to convert the map encoded in the problem syntax to a structure useful for the algorithm
    It works as follow:
    - use the original map to generate a mask (numpy matrix) where walls are encoded by 0s and any other cell is set to 1.
    - still using the original map, create a numpy matrix where 
    """
